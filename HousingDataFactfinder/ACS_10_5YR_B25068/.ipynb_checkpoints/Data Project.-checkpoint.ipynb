# %%
from datascience import *

# %%
import numpy as np

# %%
housing = Table.read_table('ACS_10_5YR_B25068_metadata.csv')
housing
# Out:
# GEO.id            | Id
# GEO.id2           | Id2
# GEO.display-label | Geography
# HD01_VD01         | Estimate; Total:
# HD02_VD01         | Margin of Error; Total:
# HD01_VD02         | Estimate; No bedroom:
# HD02_VD02         | Margin of Error; No bedroom:
# HD01_VD03         | Estimate; No bedroom: - With cash rent:
# HD02_VD03         | Margin of Error; No bedroom: - With cash rent:
# HD01_VD04         | Estimate; No bedroom: - With cash rent: - Less than $200
# HD02_VD04         | Margin of Error; No bedroom: - With cash rent: - Less th ...
# ... (66 rows omitted)

# %%
housing1 = Table.read_table('ACS_10_5YR_B25068_with_ann.csv')
housing1
# Out:
# GEO.id           | GEO.id2 | GEO.display-label         | HD01_VD01        | HD02_VD01               | HD01_VD02             | HD02_VD02                    | HD01_VD03                               | HD02_VD03                                      | HD01_VD04                                                | HD02_VD04                                                    | HD01_VD05                                              | HD02_VD05                                                    | HD01_VD06                                              | HD02_VD06                                                    | HD01_VD07                                              | HD02_VD07                                                    | HD01_VD08                                              | HD02_VD08                                                    | HD01_VD09                                                | HD02_VD09                                                    | HD01_VD10                 
# ...

# %%
housing2 = Table.read_table('ACS_10_5YR_B25111_with_ann.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-d50c58c28afd> in <module>()
# ----> 1 housing2 = Table.read_table('ACS_10_5YR_B25111_with_ann.csv')
#
# /Users/kshitijdhanuka/anaconda/lib/python3.6/site-packages/datascience/tables.py in read_table(cls, filepath_or_buffer, *args, **vargs)
#     130         except AttributeError:
#     131             pass
# --> 132         df = pandas.read_table(filepath_or_buffer, *args, **vargs)
#     133         return cls.from_df(df)
#     134
#
# ...
