# %%
from datascience import *

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
housing = Table.read_table('ACS_11_5YR_B25111_with_ann.csv')
housing
# Out:
# GEO.id           | GEO.id2 | GEO.display-label         | HD01_VD02                               | HD02_VD02                                      | HD01_VD03                                                    | HD02_VD03                                                    | HD01_VD04                                                    | HD02_VD04                                                    | HD01_VD05                                                    | HD02_VD05                                                    | HD01_VD06                                                    | HD02_VD06                                                    | HD01_VD07                                                    | HD02_VD07                                                    | HD01_VD08                                                    | HD02_VD08                                                    | HD01_VD09                                                    | HD02_VD09                      
# ...

# %%
housing1 = Table.read_table('ACS_12_5YR_B25068_with_ann.csv')
housing1
# Out:
# GEO.id           | GEO.id2 | GEO.display-label         | HD01_VD01        | HD02_VD01               | HD01_VD02             | HD02_VD02                    | HD01_VD03                               | HD02_VD03                                      | HD01_VD04                                                | HD02_VD04                                                    | HD01_VD05                                              | HD02_VD05                                                    | HD01_VD06                                              | HD02_VD06                                                    | HD01_VD07                                              | HD02_VD07                                                    | HD01_VD08                                              | HD02_VD08                                                    | HD01_VD09                                                | HD02_VD09                                                    | HD01_VD10                 
# ...

# %%
new_housing1 = housing1.drop('HD02_VD01').drop('HD02_VD02').drop('HD02_VD03').drop('HD02_VD04').drop('HD02_VD05').drop('HD02_VD06').drop('HD02_VD07').drop('HD02_VD08').drop('HD02_VD09').drop('HD02_VD10').drop('HD02_VD11').drop('HD02_VD12').drop('HD02_VD13').drop('HD02_VD14').drop('HD02_VD15').drop('HD02_VD16').drop('HD02_VD17').drop('HD02_VD18').drop('HD02_VD19').drop('HD02_VD20').drop('HD02_VD21').drop('HD02_VD22').drop('HD02_VD23').drop('HD02_VD24').drop('HD02_VD25').drop('HD02_VD26').drop('HD02_VD27').drop('HD02_VD28').drop('HD02_VD29').drop('HD02_VD30').drop('HD02_VD31').drop('HD02_VD32').drop('HD02_VD33').drop('HD02_VD34').drop('HD02_VD35').drop('HD02_VD36').drop('HD02_VD37').where('GEO.display-label', 'California').drop('GEO.display-label').drop('GEO.id').drop('GEO.id2')

new_housing_11 = new_housing1.drop('HD01_VD10').drop('HD01_VD11').drop('HD01_VD12').drop('HD01_VD13').drop('HD01_VD14').drop('HD01_VD15').drop('HD01_VD16').drop('HD01_VD17').drop('HD01_VD18').drop('HD01_VD19').drop('HD01_VD20').drop('HD01_VD21').drop('HD01_VD22').drop('HD01_VD23').drop('HD01_VD24').drop('HD01_VD25').drop('HD01_VD26').drop('HD01_VD27').drop('HD01_VD28').drop('HD01_VD29').drop('HD01_VD30').drop('HD01_VD31').drop('HD01_VD32').drop('HD01_VD33').drop('HD01_VD34').drop('HD01_VD35').drop('HD01_VD36').drop('HD01_VD37')

new_housing111 = housing1.drop('HD02_VD01').drop('HD02_VD02').drop('HD02_VD03').drop('HD02_VD04').drop('HD02_VD05').drop('HD02_VD06').drop('HD02_VD07').drop('HD02_VD08').drop('HD02_VD09').drop('HD02_VD10').drop('HD02_VD11').drop('HD02_VD12').drop('HD02_VD13').drop('HD02_VD14').drop('HD02_VD15').drop('HD02_VD16').drop('HD02_VD17').drop('HD02_VD18').drop('HD02_VD19').drop('HD02_VD20').drop('HD02_VD21').drop('HD02_VD22').drop('HD02_VD23').drop('HD02_VD24').drop('HD02_VD25').drop('HD02_VD26').drop('HD02_VD27').drop('HD02_VD28').drop('HD02_VD29').drop('HD02_VD30').drop('HD02_VD31').drop('HD02_VD32').drop('HD02_VD33').drop('HD02_VD34').drop('HD02_VD35').drop('HD02_VD36').drop('HD02_VD37').where('GEO.display-label', 'Berkeley city, California').drop('GEO.display-label').drop('GEO.id').drop('GEO.id2')

new_housing_111 = new_housing111.drop('HD01_VD10').drop('HD01_VD11').drop('HD01_VD12').drop('HD01_VD13').drop('HD01_VD14').drop('HD01_VD15').drop('HD01_VD16').drop('HD01_VD17').drop('HD01_VD18').drop('HD01_VD19').drop('HD01_VD20').drop('HD01_VD21').drop('HD01_VD22').drop('HD01_VD23').drop('HD01_VD24').drop('HD01_VD25').drop('HD01_VD26').drop('HD01_VD27').drop('HD01_VD28').drop('HD01_VD29').drop('HD01_VD30').drop('HD01_VD31').drop('HD01_VD32').drop('HD01_VD33').drop('HD01_VD34').drop('HD01_VD35').drop('HD01_VD36').drop('HD01_VD37')

new_housing11 = housing1.drop('HD02_VD01').drop('HD02_VD02').drop('HD02_VD03').drop('HD02_VD04').drop('HD02_VD05').drop('HD02_VD06').drop('HD02_VD07').drop('HD02_VD08').drop('HD02_VD09').drop('HD02_VD10').drop('HD02_VD11').drop('HD02_VD12').drop('HD02_VD13').drop('HD02_VD14').drop('HD02_VD15').drop('HD02_VD16').drop('HD02_VD17').drop('HD02_VD18').drop('HD02_VD19').drop('HD02_VD20').drop('HD02_VD21').drop('HD02_VD22').drop('HD02_VD23').drop('HD02_VD24').drop('HD02_VD25').drop('HD02_VD26').drop('HD02_VD27').drop('HD02_VD28').drop('HD02_VD29').drop('HD02_VD30').drop('HD02_VD31').drop('HD02_VD32').drop('HD02_VD33').drop('HD02_VD34').drop('HD02_VD35').drop('HD02_VD36').drop('HD02_VD37').where('GEO.display-label', 'New York city, New York').drop('GEO.display-label').drop('GEO.id').drop('GEO.id2')

new_housing__11 = new_housing11.drop('HD01_VD10').drop('HD01_VD11').drop('HD01_VD12').drop('HD01_VD13').drop('HD01_VD14').drop('HD01_VD15').drop('HD01_VD16').drop('HD01_VD17').drop('HD01_VD18').drop('HD01_VD19').drop('HD01_VD20').drop('HD01_VD21').drop('HD01_VD22').drop('HD01_VD23').drop('HD01_VD24').drop('HD01_VD25').drop('HD01_VD26').drop('HD01_VD27').drop('HD01_VD28').drop('HD01_VD29').drop('HD01_VD30').drop('HD01_VD31').drop('HD01_VD32').drop('HD01_VD33').drop('HD01_VD34').drop('HD01_VD35').drop('HD01_VD36').drop('HD01_VD37')
result = []
result1 = []
result2 = []
abcd = new_housing_11
efgh = new_housing_111
ijkl = new_housing__11

i = 3
while i < 9:
    temp = abcd[i]
    temp2 = int(temp[0])
    result.append(temp2)
    i = i + 1
    

i = 3
while i < 9:
    temp = efgh[i]
    temp2 = int(temp[0])
    result1.append(temp2)
    i = i + 1

i = 3
while i < 9:
    temp = ijkl[i]
    temp2 = int(temp[0])
    result2.append(temp2)
    i = i + 1

print(result) 
print(result1)

plt.plot(result, [200, 300, 500, 750, 1000, 1500])
# Out:
# [4934, 17752, 29541, 85145, 101028, 128110]
# [40, 240, 97, 590, 836, 1275]

# %%
plt.plot(result1, [20, 40, 60, 75, 100, 150])

# %%
plt.plot(result2, [200, 300, 500, 750, 1000, 1500])

# %%
new_housing_12 = new_housing1.drop('HD01_VD01').drop('HD01_VD02').drop('HD01_VD03').drop('HD01_VD04').drop('HD01_VD05').drop('HD01_VD06').drop('HD01_VD07').drop('HD01_VD08').drop('HD01_VD09').drop('HD01_VD10').drop('HD01_VD11').drop('HD01_VD12').drop('HD01_VD19').drop('HD01_VD20').drop('HD01_VD21').drop('HD01_VD22').drop('HD01_VD23').drop('HD01_VD24').drop('HD01_VD25').drop('HD01_VD26').drop('HD01_VD27').drop('HD01_VD28').drop('HD01_VD29').drop('HD01_VD30').drop('HD01_VD31').drop('HD01_VD32').drop('HD01_VD33').drop('HD01_VD34').drop('HD01_VD35').drop('HD01_VD36').drop('HD01_VD37')
result = []
result1 = []
result2 = []
abcd = new_housing_12

i = 0
while i < 6:
    temp = abcd[i]
    temp2 = int(temp[0])
    result.append(temp2)
    i = i + 1


plt.plot(result, [200, 300, 500, 750, 1000, 1500])

# %%
housing2 = Table.read_table('ACS_12_5YR_B25111_with_ann.csv')
housing2
# Out:
# GEO.id           | GEO.id2 | GEO.display-label         | HD01_VD02                               | HD02_VD02                                      | HD01_VD03                                                    | HD02_VD03                                                    | HD01_VD04                                                    | HD02_VD04                                                    | HD01_VD05                                                    | HD02_VD05                                                    | HD01_VD06                                                    | HD02_VD06                                                    | HD01_VD07                                                    | HD02_VD07                                                    | HD01_VD08                                                    | HD02_VD08                                                    | HD01_VD09                                                    | HD02_VD09                      
# ...

# %%
new_housing2 = housing2.drop('HD02_VD02').drop('HD02_VD03').drop('HD02_VD04').drop('HD02_VD05').drop('HD02_VD06').drop('HD02_VD07').drop('HD02_VD08').drop('HD02_VD09').drop('HD02_VD10').drop('HD02_VD11')
new_housing2
# Out:
# GEO.id           | GEO.id2 | GEO.display-label         | HD01_VD02                               | HD01_VD03                                                    | HD01_VD04                                                    | HD01_VD05                                                    | HD01_VD06                                                    | HD01_VD07                                                    | HD01_VD08                                                    | HD01_VD09                                                    | HD01_VD10                                                    | HD01_VD11
# ...

# %%
result = []
result1 = []
result2 = []
abcd = new_housing2.where('GEO.display-label', 'Berkeley city, California').drop('GEO.display-label').drop('GEO.id').drop('GEO.id2')
efgh = new_housing2.where('GEO.display-label', 'California').drop('GEO.display-label').drop('GEO.id').drop('GEO.id2')
ijkl = new_housing2.where('GEO.display-label', 'New York city, New York').drop('GEO.display-label').drop('GEO.id').drop('GEO.id2')


i = 0
while i < 10:
    temp = abcd[i]
    temp2 = int(temp[0])
    result.append(temp2)
    i = i + 1

result 

i = 0
while i < 10:
    temp = efgh[i]
    temp2 = int(temp[0])
    result1.append(temp2)
    i = i + 1

result1   


i = 0
while i < 10:
    temp = ijkl[i]
    temp2 = int(temp[0])
    result2.append(temp2)
    i = i + 1

result2  
# abcd[1]

# for i in range(len(abcd)):
#    result.append(abcd[i])

# result
plt.plot(result, [2011, 2010, 2000, 1990, 1980, 1970, 1960, 1950, 1940, 1930])
plt.plot(result1, [2011, 2010, 2000, 1990, 1980, 1970, 1960, 1950, 1940, 1930])
plt.plot(result2, [2011, 2010, 2000, 1990, 1980, 1970, 1960, 1950, 1940, 1930])

# %%
housing3 = Table.read_table('ACS_13_5YR_B25068_with_ann.csv')
housing3.drop('HD02_VD01').drop('HD02_VD02').drop('HD02_VD03').drop('HD02_VD04').drop('HD02_VD05').drop('HD02_VD06').drop('HD02_VD07').drop('HD02_VD08').drop('HD02_VD09').drop('HD02_VD10').drop('HD02_VD11').drop('HD02_VD12').drop('HD02_VD13').drop('HD02_VD14').drop('HD02_VD15').drop('HD02_VD16').drop('HD02_VD17').drop('HD02_VD18').drop('HD02_VD19').drop('HD02_VD20').drop('HD02_VD21').drop('HD02_VD22').drop('HD02_VD23').drop('HD02_VD24').drop('HD02_VD25').drop('HD02_VD26').drop('HD02_VD27').drop('HD02_VD28').drop('HD02_VD29').drop('HD02_VD30').drop('HD02_VD31').drop('HD02_VD32').drop('HD02_VD33').drop('HD02_VD34').drop('HD02_VD35').drop('HD02_VD36').drop('HD02_VD37')
# Out:
# GEO.id           | GEO.id2 | GEO.display-label         | HD01_VD01        | HD01_VD02             | HD01_VD03                               | HD01_VD04                                                | HD01_VD05                                              | HD01_VD06                                              | HD01_VD07                                              | HD01_VD08                                              | HD01_VD09                                                | HD01_VD10                            | HD01_VD11            | HD01_VD12                              | HD01_VD13                                               | HD01_VD14                                             | HD01_VD15                                             | HD01_VD16                                             | HD01_VD17                                             | HD01_VD18                                               | HD01_VD19                           | HD01_VD20             | HD01_
# ...

# %%
housing3.drop('HD02_VD01').drop('HD02_VD02').drop('HD02_VD03').drop('HD02_VD04').drop('HD02_VD05').drop('HD02_VD06').drop('HD02_VD07').drop('HD02_VD08').drop('HD02_VD09').drop('HD02_VD10').drop('HD02_VD11').drop('HD02_VD12').drop('HD02_VD13').drop('HD02_VD14').drop('HD02_VD15').drop('HD02_VD16').drop('HD02_VD17').drop('HD02_VD18').drop('HD02_VD19').drop('HD02_VD20').drop('HD02_VD21').drop('HD02_VD22').drop('HD02_VD23').drop('HD02_VD24').drop('HD02_VD25').drop('HD02_VD26').drop('HD02_VD27').drop('HD02_VD28').drop('HD02_VD29').drop('HD02_VD30').drop('HD02_VD31').drop('HD02_VD32').drop('HD02_VD33').drop('HD02_VD34').drop('HD02_VD35').drop('HD02_VD36').drop('HD02_VD37')
# Out:
# GEO.id           | GEO.id2 | GEO.display-label         | HD01_VD01        | HD01_VD02             | HD01_VD03                               | HD01_VD04                                                | HD01_VD05                                              | HD01_VD06                                              | HD01_VD07                                              | HD01_VD08                                              | HD01_VD09                                                | HD01_VD10                            | HD01_VD11            | HD01_VD12                              | HD01_VD13                                               | HD01_VD14                                             | HD01_VD15                                             | HD01_VD16                                             | HD01_VD17                                             | HD01_VD18                                               | HD01_VD19                           | HD01_VD20             | HD01_
# ...

# %%
housing4 = Table.read_table('ACS_13_5YR_B25111_with_ann.csv')
housing4.drop('HD02_VD01').drop('HD02_VD02').drop('HD02_VD03').drop('HD02_VD04').drop('HD02_VD05').drop('HD02_VD06').drop('HD02_VD07').drop('HD02_VD08').drop('HD02_VD09').drop('HD02_VD10').drop('HD02_VD11')
# Out:
# GEO.id           | GEO.id2 | GEO.display-label         | HD01_VD02                               | HD01_VD03                                                    | HD01_VD04                                                    | HD01_VD05                                                    | HD01_VD06                                                    | HD01_VD07                                                    | HD01_VD08                                                    | HD01_VD09                                                    | HD01_VD10                                                    | HD01_VD11
# ...

# %%
housing5 = Table.read_table('ACS_14_5YR_B25068_with_ann.csv')
housing5.drop('HD02_VD01').drop('HD02_VD02').drop('HD02_VD03').drop('HD02_VD04').drop('HD02_VD05').drop('HD02_VD06').drop('HD02_VD07').drop('HD02_VD08').drop('HD02_VD09').drop('HD02_VD10').drop('HD02_VD11').drop('HD02_VD12').drop('HD02_VD13').drop('HD02_VD14').drop('HD02_VD15').drop('HD02_VD16').drop('HD02_VD17').drop('HD02_VD18').drop('HD02_VD19').drop('HD02_VD20').drop('HD02_VD21').drop('HD02_VD22').drop('HD02_VD23').drop('HD02_VD24').drop('HD02_VD25').drop('HD02_VD26').drop('HD02_VD27').drop('HD02_VD28').drop('HD02_VD29').drop('HD02_VD30').drop('HD02_VD31').drop('HD02_VD32').drop('HD02_VD33').drop('HD02_VD34').drop('HD02_VD35').drop('HD02_VD36').drop('HD02_VD37')
# Out:
# GEO.id           | GEO.id2 | GEO.display-label         | HD01_VD01        | HD01_VD02             | HD01_VD03                               | HD01_VD04                                                | HD01_VD05                                              | HD01_VD06                                              | HD01_VD07                                              | HD01_VD08                                              | HD01_VD09                                                | HD01_VD10                            | HD01_VD11            | HD01_VD12                              | HD01_VD13                                               | HD01_VD14                                             | HD01_VD15                                             | HD01_VD16                                             | HD01_VD17                                             | HD01_VD18                                               | HD01_VD19                           | HD01_VD20             | HD01_
# ...

# %%
housing6 = Table.read_table('ACS_14_5YR_B25111_with_ann.csv')
housing6
# Out:
# GEO.id           | GEO.id2 | GEO.display-label         | HD01_VD02                               | HD02_VD02                                      | HD01_VD03                                                    | HD02_VD03                                                    | HD01_VD04                                                    | HD02_VD04                                                    | HD01_VD05                                                    | HD02_VD05                                                    | HD01_VD06                                                    | HD02_VD06                                                    | HD01_VD07                                                    | HD02_VD07                                                    | HD01_VD08                                                    | HD02_VD08                                                    | HD01_VD09                                                    | HD02_VD09                      
# ...

# %%
housing7 = Table.read_table('ACS_15_5YR_B25068_with_ann.csv')
housing7
# Out:
# GEO.id           | GEO.id2 | GEO.display-label         | HD01_VD01        | HD02_VD01               | HD01_VD02             | HD02_VD02                    | HD01_VD03                               | HD02_VD03                                      | HD01_VD04                                                | HD02_VD04                                                    | HD01_VD05                                              | HD02_VD05                                                    | HD01_VD06                                              | HD02_VD06                                                    | HD01_VD07                                              | HD02_VD07                                                    | HD01_VD08                                                  | HD02_VD08                                                    | HD01_VD09                                                | HD02_VD09                                                    | HD01_VD10             
# ...

# %%
housing8 = Table.read_table('ACS_15_5YR_B25111_with_ann.csv')
housing8
# Out:
# GEO.id           | GEO.id2 | GEO.display-label         | HD01_VD02                               | HD02_VD02                                      | HD01_VD03                                                    | HD02_VD03                                                    | HD01_VD04                                           | HD02_VD04                                                  | HD01_VD05                                                    | HD02_VD05                                                    | HD01_VD06                                                    | HD02_VD06                                                    | HD01_VD07                                                    | HD02_VD07                                                    | HD01_VD08                                                    | HD02_VD08                                                    | HD01_VD09                                                    | HD02_VD09                                 
# ...
