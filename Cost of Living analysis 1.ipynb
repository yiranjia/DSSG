# %%
### Cost of living, specifically housing price (Berkeley, CA)
### Def: the level of prices relating to a range of everyday items.

### Elena & Tiffany

import matplotlib.pyplot as plt
import pandas
import numpy as np
import matplotlib
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ## Visualization

# %% [markdown]
# #### Tutorials
#
# http://matplotlib.org/gallery.html
#
# http://matplotlib.org/users/pyplot_tutorial.html
#
# http://pandas.pydata.org/pandas-docs/stable/10min.html
#
# http://seaborn.pydata.org/tutorial.html

# %% [markdown]
# ## 1 Pie chart of college cost
# Pie Chart of total student costs (Berkeley and other colleges)

# %%
# 
# Total pie
# Housing
# Tuition
# Textbook
# Health

# %% [markdown]
# ### College Board: Average Estimated Undergraduate Budgets, 2016-17

# %%
# https://trends.collegeboard.org/college-pricing/figures-tables/average-estimated-undergraduate-budgets-2016-17

# %%
# Private Nonprofit Four-Year On-Campus

labels = 'Tuition', 'Housing', 'Books', 'Transportation','Other'
total = 49320
print ("total", total)
sizes = [33480/total, 11890/total, 1230/total, 1070/total, 1650/total]


fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# Apart from tuition


labels = 'Housing', 'Books', 'Transportation','Other'
total = 49320 - 33480
print ("total apart from tuition", total)
sizes = [11890/total, 1230/total, 1070/total, 1650/total]


fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
# Out:
# total 49320
# total apart from tuition 15840

# %%
# Public Four-Year Out-of-State On-Campus
labels = 'Tuition', 'Housing', 'Books', 'Transportation','Other'
total = 39890
print ("total", total)
sizes = [24930/total, 10440/total, 1250/total, 1160/total, 2110/total]


fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# Public Four-Year In-State On-Campus	$9,650	$10,440	$1,250	$1,160	$2,110	$24,610

labels = 'Tuition', 'Housing', 'Books', 'Transportation','Other'
total = 24610
print ("total", total)
sizes = [9650/total, 10440/total, 1250/total, 1160/total, 2110/total]


fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()

# Apart from tuition

labels = 'Housing', 'Books', 'Transportation','Other'
total = 39890 - 24930
print ("total apart from tuition", total)
sizes = [10440/total, 1250/total, 1160/total, 2110/total]

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
# Out:
# total 39890
# total 24610
# total apart from tuition 14960

# %%
from IPython.display import Image
Image("cp-2016-figure-1.png")

# %% [markdown]
# ### Trends College Pricing (ideas / big pictures)
#
# https://tcf.org/content/report/the-real-price-of-college/
#
# http://trends.collegeboard.org/sites/default/files/2015-trends-college-pricing-final-508.pdf

# %% [markdown]
# ### Housing and Utilities (general)
# http://www.studying-in-us.org/cost-of-living-in-the-united-states/
#
# budget approximately $1000 – $1500 per month for housing and utilities

# %%
sns.set(style="white", context="talk")
rs = np.random.RandomState(7)

# Set up the matplotlib figure
f, (ax1) = plt.subplots(1, 1, figsize=(8, 6), sharex=True)

x = ['electric','gas', 'internect','celullar','water, trash']
y1 = [100, 10, 50, 50, 20]
sns.barplot(x, y1, palette="RdBu_r", ax=ax1)
ax1.set_ylabel("Sequential")

# %%
###Example

sns.set(style="white", context="talk")
rs = np.random.RandomState(7)


# Set up the matplotlib figure
f, (ax1, ax2, ax3) = plt.subplots(3, 1, figsize=(8, 6), sharex=True)

# Generate some sequential data
x = np.array(list("ABCDEFGHI"))
y1 = np.arange(1, 10)
sns.barplot(x, y1, palette="BuGn_d", ax=ax1)
ax1.set_ylabel("Sequential")

# Center the data to make it diverging
y2 = y1 - 5
sns.barplot(x, y2, palette="RdBu_r", ax=ax2)
ax2.set_ylabel("Diverging")

# Randomly reorder the data to make it qualitative
y3 = rs.choice(y1, 9, replace=False)
sns.barplot(x, y3, palette="Set3", ax=ax3)
ax3.set_ylabel("Qualitative")

# Finalize the plot
sns.despine(bottom=True)
plt.setp(f.axes, yticks=[])
plt.tight_layout(h_pad=3)

# %% [markdown]
# ### Berkeley Estimated Cost 2017-2018
# Living in an Off-Campus Apartment
# http://financialaid.berkeley.edu/cost-attendance

# %%
labels = 'Tuition', 'Housing', 'Food','Books', 'Personal','Transportation'
total = 30540
print ("total", total)
sizes = [14068/total, 8992/total, 4264/total, 894/total, 1780/total, 542/total]


fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()


# Apart from tuition

labels = 'Housing', 'Food','Books', 'Personal','Transportation'
total = 30540 - 14068
print ("total apart from tuition", total)
sizes = [8992/total, 4264/total, 894/total, 1780/total, 542/total]

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%',
        shadow=True, startangle=90)
ax1.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.

plt.show()
# Out:
# total 30540
# total apart from tuition 16472

# %% [markdown]
# Berkeley: International student http://internationaloffice.berkeley.edu/students/current/expenses

# %% [markdown]
# ## 2 Housing @ Berkeley
# student housing costs (Berkeley)
