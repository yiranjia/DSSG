# %% [markdown]
# ### Relationship btw College Housing and Region (california specific)
# https://www.usnews.com/education/best-colleges/the-short-list-college/articles/2016-05-17/10-colleges-that-charge-the-most-for-room-and-board

# %% [markdown]
# https://www.numbeo.com/cost-of-living/in/Berkeley

# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import matplotlib
import seaborn as sns
# %matplotlib inline

# %% [markdown]
# ### BI map
#
# http://www.businessinsider.com/most-expensive-college-dorms-map-2014-10
#
# http://www.dailycal.org/2015/03/13/uc-berkeley-campus-housing-prices-rank-among-highest-nation/

# %% [markdown]
# ### Analyzing housing price (http://aakashjapi.com/housing-prices-in-berkeley/)
#
# http://aakashjapi.com/images/general_histogram.png
#
# https://www.google.com/maps/d/u/0/viewer?mid=1u-f1t-eIivnQQ8R1r67b3TuRfTE&ll=37.877591351462385%2C-122.26998060000005&z=15
#
# https://www.google.com/maps/d/u/0/viewer?mid=1JVcUdic5mWU80o5ntcWqmzSlWTM&ll=37.871465783789844%2C-122.25959305000003&z=15

# %% [markdown]
# ### Californian college housing data
# https://www.usnews.com/education/best-colleges/the-short-list-college/articles/2016-05-17/10-colleges-that-charge-the-most-for-room-and-board

# %% [markdown]
# #School name (state)	2015-2016 room and board	U.S. News rank and category
#
# California collegs:
#
# Berkeley,
# UCLA,
# UCSD,
# USC,
# Pomona,
# UCSB,
# UCSC,
# Caltech,
# Stamford,
# San Francisco State,
# Pepperdine,

# %%
price = [16056, 15716, 15441, 15150, 14796,14348, 14330, 14107 ,13882, 13605, 12545]
college = ['UCSC', 'Berkeley', 'UCLA',  'Pomona','Caltech','USC', 'Pepperdine' , 'Stanford','San Francisco State','UCSB','UCSD']
# location = ["NYC", "NYC", "NYC",'San Diego','LA','Boston','Dallas','NYC','Northampton','Berkeley']

# %%
# a = list(zip(price, college,location))

a = []
i = 0
while i < 11:
    a.append([price[i], college[i]])
    i = i + 1

dfa = pd.DataFrame(a)
print (dfa)
# Out:
#         0                    1
# 0   16056                 UCSC
# 1   15716             Berkeley
# 2   15441                 UCLA
# 3   15150               Pomona
# 4   14796              Caltech
# 5   14348                  USC
# 6   14330           Pepperdine
# 7   14107             Stanford
# 8   13882  San Francisco State
# 9   13605                 UCSB
# 10  12545                 UCSD

# %%
# Food: Meal, Inexpensive Restaurant
# Transportatidon: Taxi 1 mile (Normal Tariff)
# Utilities (Monthly): Basic (Electricity, Heating, Water, Garbage) for 915 sq ft Apartment	
# Clothing And Shoes: 1 Pair of Jeans (Levis 501 Or Similar)
# Rent Per Month: Apartment (1 bedroom) in City Centre
# Rent Per Month: Apartment (1 bedroom) Outside of Centre
# Salaries And Financing

# %% [markdown]
# ### Data source:
# https://www.numbeo.com/cost-of-living/in/Berkeley

# %% [markdown]
# #### food , price

# %%
food = [12, 15, 14.5, 15, 12, 16, 15, 15, 10, 15, 15]

# %%
plt.plot(price,food)

# %%
d1 = {'price' : price,
     'two' : food}
df111 = pd.DataFrame(d1)

# %%
print (df111)
# Out:
#     price   two
# 0   16056  12.0
# 1   15716  15.0
# 2   15441  14.5
# 3   15150  15.0
# 4   14796  12.0
# 5   14348  16.0
# 6   14330  15.0
# 7   14107  15.0
# 8   13882  10.0
# 9   13605  15.0
# 10  12545  15.0

# %%
g = sns.lmplot(x="price", y="two", data=df111)

# %% [markdown]
# #### Transportation

# %%
taxi = [3.9, 2.78, 3, 2.78, 3.78, 3.25, 3,3.78, 4, 2.75, 2.78]

# %%
plt.plot(price,taxi)

# %%
d2 = {'price' : price,
     'taxi' : taxi}
df222 = pd.DataFrame(d2)

# %%
print (df222)
# Out:
#     price  taxi
# 0   16056  3.90
# 1   15716  2.78
# 2   15441  3.00
# 3   15150  2.78
# 4   14796  3.78
# 5   14348  3.25
# 6   14330  3.00
# 7   14107  3.78
# 8   13882  4.00
# 9   13605  2.75
# 10  12545  2.78

# %%
g = sns.lmplot(x="price", y="taxi", data=df222)

# %% [markdown]
# ### Utilities

# %%
util = [131.22, 126.75, 134.76, 148.75, 141.32, 134.76, 134.35,127.22, 110.38, 117.46, 116.09]

# %%
plt.plot(price,util)

# %%
d3 = {'price' : price,
     'util' : util}
df3 = pd.DataFrame(d3)

# %%
print (df3)
# Out:
#     price    util
# 0   16056  131.22
# 1   15716  126.75
# 2   15441  134.76
# 3   15150  148.75
# 4   14796  141.32
# 5   14348  134.76
# 6   14330  134.35
# 7   14107  127.22
# 8   13882  110.38
# 9   13605  117.46
# 10  12545  116.09

# %%
g = sns.lmplot(x="price", y="util", data=df3)

# %% [markdown]
# ### Salaries and Financing

# %%
finance = [4733.33, 3366.67, 3706.81, 2469.72, 4087.33, 3706.81, 2650, 6200, 4455.16, 3414.60, 3778.11]

# %%
plt.plot(price,finance)

# %%
d4 = {'price' : price,
     'finance' : finance}
df4 = pd.DataFrame(d4)

# %%
g = sns.lmplot(x="price", y="finance", data = df4)

# %% [markdown]
# ### Rent city center

# %%
rent_c = [1731.82, 2077.78, 1938.77, 966.67, 1914.50, 1938.77, 2612.50, 2733.33, 3337.16, 1837.50, 1813.30]

# %%
plt.plot(price, rent_c)

# %%
d5 = {'price' : price,
     'rent_center' : rent_c}
df5 = pd.DataFrame(d5)

# %%
g = sns.lmplot(x="price", y="rent_center", data = df5)

# %% [markdown]
# ### rent outside center

# %%
rent_o_c = [1533.33, 1655.56, 1430.12, 1025, 1641.70, 1430.12, 2000, 2275, 2563.44, 1590, 1344.27]

# %%
plt.plot(price, rent_o_c)

# %%
d6 = {'price' : price,
     'rent_outside_center' : rent_o_c}
df6 = pd.DataFrame(d6)

# %%
g = sns.lmplot(x="price", y="rent_outside_center", data = df6)

# %% [markdown]
# ## Clothing And Shoes: 1 Pair of Jeans (Levis 501 Or Similar)

# %%
clothing = [46, 57.78, 48.67, 40, 45.67, 48.67, 48.67, 39,63.56, 45.88, 43.95]

# %%
plt.plot(price, clothing)

# %%
d7 = {'price' : price,
     'clothing' : clothing}
df7 = pd.DataFrame(d7)

# %%
g = sns.lmplot(x="price", y="clothing", data = df7)

# %% [markdown]
# ### Seaborn
# http://seaborn.pydata.org/generated/seaborn.heatmap.html

# %% [markdown]
# ### Seaborn linear
# http://seaborn.pydata.org/generated/seaborn.lmplot.html
